# %% [markdown]
# #Importing all the required Libraries to solve the problem statment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline

# %% [markdown]
# #Importing and Preprocessing the data

# %%
data = pd.read_csv('musk_csv.csv')

# %%
data.head()
# Out:
#    ID molecule_name conformation_name  f1   f2  ...  f163  f164  f165  f166  class
# 0   1      MUSK-211           211_1+1  46 -108  ...   156   -50  -112    96      1
# 1   2      MUSK-211          211_1+10  41 -188  ...   169   -61  -136    79      1
# 2   3      MUSK-211          211_1+11  46 -194  ...   165   -67  -145    39      1
# 3   4      MUSK-211          211_1+12  41 -188  ...   168   -60  -135    80      1
# 4   5      MUSK-211          211_1+13  41 -188  ...   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
data.tail()
# Out:
#         ID  molecule_name conformation_name  f1  ...  f164  f165  f166  class
# 6593  6594  NON-MUSK-jp13          jp13_2+5  51  ...   -44  -115   118      0
# 6594  6595  NON-MUSK-jp13          jp13_2+6  44  ...   -66  -144    -5      0
# 6595  6596  NON-MUSK-jp13          jp13_2+7  44  ...   -66  -144    -6      0
# 6596  6597  NON-MUSK-jp13          jp13_2+8  51  ...   -44  -116   117      0
# 6597  6598  NON-MUSK-jp13          jp13_2+9  51  ...   -44  -115   118      0
#
# [5 rows x 170 columns]

# %%
data.shape
# Out:
# (6598, 170)

# %%
data=data.drop("ID", axis=1)
data=data.drop("molecule_name", axis=1)
data=data.drop("conformation_name", axis=1)
data.head()
# Out:
#    f1   f2   f3  f4   f5  f6  f7  ...  f161  f162  f163  f164  f165  f166  class
# 0  46 -108  -60 -69 -117  49  38  ...    39   126   156   -50  -112    96      1
# 1  41 -188 -145  22 -117  -6  57  ...   103   136   169   -61  -136    79      1
# 2  46 -194 -145  28 -117  73  57  ...   143   142   165   -67  -145    39      1
# 3  41 -188 -145  22 -117  -7  57  ...   104   136   168   -60  -135    80      1
# 4  41 -188 -145  22 -117  -7  57  ...   104   137   168   -60  -135    80      1
#
# [5 rows x 167 columns]

# %%
data.shape
# Out:
# (6598, 167)

# %%
sns.set()

# %%
sns.countplot(x='class',data=data)
plt.show()

# %%
X = data.drop('class',axis=1) #we are droping the last column because i.e., labelled data
X.head()
# Out:
#    f1   f2   f3  f4   f5  f6  f7  ...  f160  f161  f162  f163  f164  f165  f166
# 0  46 -108  -60 -69 -117  49  38  ...    -7    39   126   156   -50  -112    96
# 1  41 -188 -145  22 -117  -6  57  ...    52   103   136   169   -61  -136    79
# 2  46 -194 -145  28 -117  73  57  ...    57   143   142   165   -67  -145    39
# 3  41 -188 -145  22 -117  -7  57  ...    52   104   136   168   -60  -135    80
# 4  41 -188 -145  22 -117  -7  57  ...    52   104   137   168   -60  -135    80
#
# [5 rows x 166 columns]

# %%
Y = data["class"]
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: class, dtype: int64

# %%
print(X.shape,Y.shape)
# Out:
# (6598, 166) (6598,)

# %% [markdown]
# #Splitting the dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=1)

# %%
X_train = X_train.T 
X_test = X_test.T 
X_train.shape
# Out:
# (166, 5278)

# %%
Y_train = np.array(Y_train) 
Y_train=Y_train.reshape(-1,1)

Y_train = Y_train.T 
Y_test = np.array(Y_test) 
Y_test=Y_test.reshape(-1,1)

Y_test = Y_test.T 
print(Y_train.shape,Y_test.shape)
# Out:
# (1, 5278) (1, 1320)

# %% [markdown]
# #We need to do build all necessary functions to calculate the cost,accuracy and Loss

# %%
def sigmoid(z):
    s = 1 / (1 + np.exp(-z))
    return s

# %%
def initialize(n_x, n_h, n_y):

    np.random.seed(2)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.random.rand(n_h, 1)
    W2 = np.random.rand(n_y, n_h) * 0.01
    b2 = np.random.rand(n_y, 1)
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}

    return parameters

# %%
def forward_prop(X, parameters):
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']

    Z1 = np.dot(W1, X) + b1
    A1 = np.tanh(Z1)
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}

    return A2, cache

# %%
def compute_cost(A2, Y, parameters):
    m = Y_train.shape[1]
    W1 = parameters['W1']
    W2 = parameters['W2']
    logprobs = np.multiply(np.log(A2), Y) + np.multiply(np.log(1 - A2), (1 - Y))
    cost = - np.sum(logprobs) / m
    cost = np.squeeze(cost)

    return cost

# %%
def back_prop(parameters, cache, X, Y):
    m = Y_train.shape[1]
    W1 = parameters['W1']
    W2 = parameters['W2']
    A1 = cache['A1']
    A2 = cache['A2']

    dZ2 = A2 - Y
    dW2 = (1 / m) * np.dot(dZ2, A1.T)
    db2 = (1 / m) * np.sum(dZ2, axis=1, keepdims=True)

    dZ1 = np.multiply(np.dot(W2.T, dZ2), 1 - np.square(A1))
    dW1 = (1 / m) * np.dot(dZ1, X.T)
    db1 = (1 / m) * np.sum(dZ1, axis=1, keepdims=True)

    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}

    return grads

# %%
def update_params(parameters, grads, alpha):
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']

    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']

    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1
    W2 = W2 - alpha * dW2
    b2 = b2 - alpha * db2

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    return parameters

# %%
def predict(parameters, X,Y):
    A2, cache = forward_prop(X, parameters)
    predictions = np.round(A2)
    cost_test = compute_cost(A2, Y, parameters)
    return predictions,cost_test

# %%
def model(X, Y, num_iters=2600, alpha=0.1, print_cost=True):
    np.random.seed(3)
    
    parameters = initialize(n_x=X_train.shape[0],n_h= 120,n_y=Y_train.shape[0])
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']

    costs_train = []
    costs_test = []
    accuracy_train = []
    accuracy_test= []  
    for i in range(0, num_iters):

        A2, cache = forward_prop(X, parameters)

        cost = compute_cost(A2, Y, parameters)
#         print(cost.shape)
        grads = back_prop(parameters, cache, X, Y)
    
        parameters = update_params(parameters, grads, alpha)
        
        if print_cost  and i % 100 == 0:
            m=X.shape[1]
            p=np.zeros((1,m))
#             print ("CostTrain after iteration %i: %f" %(i, cost))
            for x in range (0,A2.shape[1]):
                if A2[0,x] >  0.5:
                    p[0,x] = 1
                else:
                    p[0,x] = 0
             
            acc_train = np.sum((p==Y)/m)
#             print ("AccuracyTrain after iteration %i: %f" %(i, acc_train ))
            
            
            predictions,cost_test = predict(parameters, X_test,Y_test)
#             print ("CostTest after iteration %i: %f" %(i, cost_test))
            acc_test=float((np.dot(Y_test, predictions.T) + np.dot(1 - Y_test, 1 - predictions.T)) / float(Y_test.size))
#             print ("AccuracyTest after iteration %i: %f" %(i, acc_test ))
            
            print('Iteration: %i Train Cost: %f || Test Cost: %f' %(i,cost,cost_test))
            print('             Train Accuracy: %f || Test Accuracy: %f' %(cost,cost_test))
            
        if print_cost and i % 100 == 0:
            costs_train.append(cost)
            costs_test.append(cost_test)
            accuracy_train.append(acc_train)
            accuracy_test.append(acc_test)
            
#     print(costs_train)
    
    plt.figure()
    plt.plot(np.squeeze(costs_train))
    plt.plot(np.squeeze(costs_test))
    plt.title('model Loss')
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    plt.figure()
    plt.plot(accuracy_train)
    plt.plot(accuracy_test)
    plt.title('model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

        
    return parameters

# %% [markdown]
# #Calculations of cost and Accuracy through iterations

# %%
parameters=model(X_train, Y_train)
# Out:
# Iteration: 0 Train Cost: 0.907440 || Test Cost: 0.106553
#              Train Accuracy: 0.907440 || Test Accuracy: 0.106553
# Iteration: 100 Train Cost: 0.286918 || Test Cost: 0.066951
#              Train Accuracy: 0.286918 || Test Accuracy: 0.066951
# Iteration: 200 Train Cost: 0.248371 || Test Cost: 0.054481
#              Train Accuracy: 0.248371 || Test Accuracy: 0.054481
# Iteration: 300 Train Cost: 0.192909 || Test Cost: 0.055443
#              Train Accuracy: 0.192909 || Test Accuracy: 0.055443
# Iteration: 400 Train Cost: 0.140911 || Test Cost: 0.037867
#              Train Accuracy: 0.140911 || Test Accuracy: 0.037867
# Iteration: 500 Train Cost: 0.188533 || Test Cost: 0.048388
#              Train Accuracy: 0.188533 || Test Accuracy: 0.048388
# Iteration: 600 Train Cost: 0.215571 || Test Cost: 0.058103
#              Train Accuracy: 0.215571 || Test Accuracy: 0.058103
# Iteration: 700 Train Cost: 0.184817 || Test Cost: 0.057247
#              Train Accuracy: 0.184817 || Test Accuracy: 0.057247
# Iteration: 800 Train Cost: 0.238051 || Test Cost: 0.060864
#              Train Accuracy: 0.238051 || Test Accuracy: 0.060864
# Iteration: 900 Train Cost: 0.243779 || Test Cost: 0.059515
#              Train Accuracy: 0.243779 || Test Accuracy: 0.059515
# Iteration: 1000 Train Cost: 0.147140 || Test Cost: 0.041120
#              Train Accuracy: 0.147140 || Test Accuracy: 0.041120
# Iteration: 1100 Train Cost: 0.115978 || Test Cost: 0.046456
#              Train Accuracy: 0.115978 || Test Accuracy: 0.046456
# Iteration: 1200 Train Cost: 0.233149 || Test Cost: 0.056411
#              Train Accuracy: 0.233149 || Test Accuracy: 0.056411
# Iteration: 1300 Train Cost: 0.199595 || Test Cost: 0.053614
#              Train Accuracy: 0.199595 || Test Accuracy: 0.053614
# Iteration: 1400 Train Cost: 0.201143 || Test Cost: 0.051181
#              Train Accuracy: 0.201143 || Test Accuracy: 0.051181
# Iteration: 1500 Train Cost: 0.223865 || Test Cost: 0.052484
#              Train Accuracy: 0.223865 || Test Accuracy: 0.052484
# Iteration: 1600 Train Cost: 0.173448 || Test Cost: 0.047816
#              Train Accuracy: 0.173448 || Test Accuracy: 0.047816
# Iteration: 1700 Train Cost: 0.221234 || Test Cost: 0.055291
#              Train Accuracy: 0.221234 || Test Accuracy: 0.055291
# Iteration: 1800 Train Cost: 0.164960 || Test Cost: 0.042811
#              Train Accuracy: 0.164960 || Test Accuracy: 0.042811
# Iteration: 1900 Train Cost: 0.170332 || Test Cost: 0.037521
#              Train Accuracy: 0.170332 || Test Accuracy: 0.037521
# Iteration: 2000 Train Cost: 0.301948 || Test Cost: 0.060260
#              Train Accuracy: 0.301948 || Test Accuracy: 0.060260
# Iteration: 2100 Train Cost: 0.187140 || Test Cost: 0.041829
#              Train Accuracy: 0.187140 || Test Accuracy: 0.041829
# Iteration: 2200 Train Cost: 0.084603 || Test Cost: 0.025629
#              Train Accuracy: 0.084603 || Test Accuracy: 0.025629
# Iteration: 2300 Train Cost: 0.074248 || Test Cost: 0.026172
#              Train Accuracy: 0.074248 || Test Accuracy: 0.026172
# Iteration: 2400 Train Cost: 0.204496 || Test Cost: 0.047312
#              Train Accuracy: 0.204496 || Test Accuracy: 0.047312
# Iteration: 2500 Train Cost: 0.199337 || Test Cost: 0.052909
#              Train Accuracy: 0.199337 || Test Accuracy: 0.052909

# %% [markdown]
# #Classification Report

# %%
print(classification_report(Y_test.T,predictions.T))
print(confusion_matrix(Y_test.T,predictions.T))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      1141
#            1       0.92      0.50      0.65       179
#
#     accuracy                           0.93      1320
#    macro avg       0.92      0.75      0.80      1320
# weighted avg       0.93      0.93      0.92      1320
#
# [[1133    8]
#  [  89   90]]

# %% [markdown]
# #Accuracy

# %%
predictions,cost_test = predict(parameters,X_test,Y_test)
print ('Accuracy: %d' % float((np.dot(Y_test, predictions.T) + np.dot(1 - Y_test, 1 - predictions.T)) / float(Y_test.size) * 100) + '%')
# Out:
# Accuracy: 92%

# %% [markdown]
# # Pickle the file,save the model and load the model using pickle library

# %%
import pickle

# %%
Pkl_Filename = "Pickle_RL_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)
